# %% [markdown]
# <a href="https://colab.research.google.com/github/datapaf/Kaggle/blob/master/titanix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Imputation
# 1. encode categorical features
# 2. scale features
# 3. dimension reduction (?)
# 4. correlating predictors

# %% [markdown]
# ### Imputation

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# * use mean value for age
# * encode cabin with NaN values (leave it for now)
# * use most frequent value for embarked
# * use most frequent value for fare

# %%
from sklearn.impute import SimpleImputer

# %%
def impute(column, strategy):
    train_imputer = SimpleImputer(strategy=strategy)
    test_imputer = SimpleImputer(strategy=strategy)

    train_df[column] = train_imputer.fit_transform(train_df[[column]])
    test_df[column] = test_imputer.fit_transform(test_df[[column]])

# %%
# age imputation

impute(column="Age", strategy="mean")

train_df['Age'] = train_df['Age'].astype(int) 
test_df['Age'] = test_df['Age'].astype(int)

# %%
# embark imputation

impute(column="Embarked", strategy="most_frequent")

# %%
# fare imputation

impute(column="Fare", strategy="most_frequent")

# %% [markdown]
# ### Encoding

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# * use OneHotEncoder for Sex
# * use OrdinalEncoder for Ticket
# * use OrdinalEncoder for Cabin
# * use OneHotEncoder for Embarked

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
def ohe(df, column):
    new_features = pd.get_dummies(df[[column]])
    new_df = pd.concat([df, new_features], axis=1)
    return new_df.drop(column, axis=1)

# %%
def ord_enc(df, column, handle_nan=False):
    enc = OrdinalEncoder()
    df[[column]] = enc.fit_transform(df[[column]]).astype(int)

# %%
# gender encoding

train_df = ohe(train_df, "Sex")
test_df = ohe(test_df, "Sex")

# %%
# ticket encoding

ord_enc(train_df, "Ticket")
ord_enc(test_df, "Ticket")

# %%
# cabin encoding

ord_enc(train_df, "Cabin", handle_nan=True)
ord_enc(test_df, "Cabin", handle_nan=True)

# %%
# embarked encoding

train_df = ohe(train_df, "Embarked")
test_df = ohe(test_df, "Embarked")

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  ... Embarked_C  Embarked_Q  Embarked_S
# 0              1         0       3  ...          0           0           1
# 1              2         1       1  ...          1           0           0
# 2              3         1       3  ...          0           0           1
# 3              4         1       1  ...          0           0           1
# 4              5         0       3  ...          0           0           1
# ..           ...       ...     ...  ...        ...         ...         ...
# 886          887         0       2  ...          0           0           1
# 887          888         1       1  ...          0           0           1
# 888          889         0       3  ...          0           0           1
# 889          890         1       1  ...          1           0           0
# 890          891         0       3  ...          0           1           0
#
# [891 rows x 15 columns]

# %% [markdown]
# ### Scaling

# %%
predictors = ["Pclass", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Sex_female", "Sex_male", "Embarked_C", "Embarked_Q", "Embarked_S"]
target = "Survived"

# %%
from sklearn.preprocessing import StandardScaler

train_sc = StandardScaler()
train_df[predictors] = train_sc.fit_transform(train_df[predictors])

test_sc = StandardScaler()
test_df[predictors] = test_sc.fit_transform(test_df[predictors])

# %%
train_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col0,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row1_col1,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col2,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col3,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row4_col4,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row5_col5,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row6_col6,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row7_col7,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row8_col8,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row9_col9,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row10_col10,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row11_col11,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row12_col12,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col1,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row7_col13{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col2{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col3,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row6_col8,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row11_col3{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col4,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col6{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col5{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col6,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row8_col4{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row0_col7,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row13_col8{
#             background-color:  #b3cdfb;
#             color:  #000000;
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col1,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row12_col5{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col3,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col7,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col8,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col4,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row4_col0,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row6_col0,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row8_col2,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row8_col6,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row9_col10,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row10_col1,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row10_col5,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row10_col9,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row11_col13,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row13_col11,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row13_col12{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col4,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row7_col12,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row13_col1{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col5,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row6_col5{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col6,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col11{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col9{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col10{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col11{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col12,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row2_col13{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col0{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col1{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col5{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col7{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row3_col8,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row4_col9,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row8_col1,#T_f4357c20_6801_11ec_a5d6_0242ac1c0002row8_col11{
#             b

# %% [markdown]
# we see some considerable correlation between:
# * Fare vs. Pclass -> Pclass
# * Cabin vs. Pclass -> Pclass
# * Sex_male vs. Sex_female -> Sex_male
# * Embarked_S vs. Embarked_C -> Embarked_C
# * Embarked_S vs. Embarked_Q -> Embarked_Q

# %%
predictors = list(set(predictors) - set(["Fare", "Cabin", "Sex_female", "Embarked_S"]))

# %%
predictors
# Out:
# ['Embarked_C',
#  'Ticket',
#  'Pclass',
#  'SibSp',
#  'Embarked_Q',
#  'Age',
#  'Sex_male',
#  'Parch']
